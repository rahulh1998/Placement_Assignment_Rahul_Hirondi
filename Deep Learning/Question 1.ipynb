# %% [markdown]
# ### Question 1 : Implement 3 different CNN architectures with a comparison table for the MNSIT dataset using the Tensorflow library

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Reshape and normalize input data
x_train = x_train.reshape(-1, 28, 28, 1) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1) / 255.0

# One-hot encode the target labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Define the first CNN architecture
model1 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
print('!!Starting Model 1 training!!')
# Compile and train the first model
model1.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model1.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
print('Model 1 trained successfully!')

# Define the second CNN architecture
model2 = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

print('!!Starting Model 2 training!!')
# Compile and train the second model
model2.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model2.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
print('Model 2 trained successfully!')


print('!!Starting Model 3 training!!')
# Define the third CNN architecture
model3 = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile and train the third model
model3.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model3.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
print('Model 3 trained successfully!')



# Evaluate the models on the test set
_, acc1 = model1.evaluate(x_test, y_test, verbose=0)
_, acc2 = model2.evaluate(x_test, y_test, verbose=0)
_, acc3 = model3.evaluate(x_test, y_test, verbose=0)

# Create a comparison table
print("CNN Architecture\t\tAccuracy")
print("-------------------------------------------------")
print("Model 1\t\t\t{:.2f}%".format(acc1 * 100))
print("Model 2\t\t\t{:.2f}%".format(acc2 * 100))
print("Model 3\t\t\t{:.2f}%".format(acc3 * 100))
# Out:
# !!Starting Model 1 training!!
# Epoch 1/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1454 - accuracy: 0.9567 - val_loss: 0.0594 - val_accuracy: 0.9804
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0487 - accuracy: 0.9849 - val_loss: 0.0507 - val_accuracy: 0.9833
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0309 - accuracy: 0.9903 - val_loss: 0.0390 - val_accuracy: 0.9864
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0202 - accuracy: 0.9937 - val_loss: 0.0457 - val_accuracy: 0.9858
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 0.0403 - val_accuracy: 0.9868
# Model 1 trained successfully!
# !!Starting Model 2 training!!
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1541 - accuracy: 0.9542 - val_loss: 0.0539 - val_accuracy: 0.9817
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0517 - accuracy: 0.9842 - val_loss: 0.0388 - val_accuracy: 0.9887
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0361 - accuracy: 0.9883 - val_loss: 0.0395 - val_accuracy: 0.9871
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0278 - accuracy: 0.9909 - val_loss: 0.0290 - val_accuracy: 0.9908
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.0388 - val_accuracy: 0.9876
# Model 2 trained successfully!
# !!Starting Model 3 training!!
# Epoch 1/5
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.1579 - accuracy: 0.9507 - val_loss: 0.0740 - val_accuracy: 0.9758
# Epoch 2/5
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0580 - accuracy: 0.9822 - val_loss: 0.0570 - val_accuracy: 0.9811
# Epoch 3/5
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0401 - accuracy: 0.9877 - val_loss: 0.0510 - val_accuracy: 0.9851
# Epoch 4/5
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0281 - accuracy: 0.9910 - val_loss: 0.0538 - val_accuracy: 0.9855
# Epoch 5/5
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0225 - accuracy: 0.9930 - val_loss: 0.0489 - val_accuracy: 0.9855
# Model 3 trained successfully!
# CNN Architecture		Accuracy
# -------------------------------------------------
# Model 1			98.68%
# Model 2			98.76%
# Model 3			98.55%
